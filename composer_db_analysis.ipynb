# %% [markdown]
# ## Importing all the csv tables
# 1. df_symphonies - a list of algos with their composer URL
# 2. df_oos - a list of OOS (out of sample) stats on individual algos
# 3. df_backtest - a list of **detail** stats based on the longest possible backtest
# 4. df_oos_stats - a list of **detail** OOS stats on individual algos

# %%
import pandas as pd

df_symphonies = pd.read_csv('bin/symphonies-2024-12-30/SYMPHONIES.csv')
df_oos = pd.read_csv('bin/symphonies-2024-12-30/OOS.csv')
df_backtest = pd.read_csv('bin/symphonies-2025-01-11/BACKTEST.csv')
df_oos_stats = pd.read_csv('bin/symphonies-2025-01-11/OOS.csv')

# %%
merged_df = pd.merge(df_symphonies, df_oos, on='symphony_sid', how='left')
merged_df = pd.merge(merged_df, df_oos_stats, left_on='symphony_sid', right_on='sid', how='left')

merged_df.shape
# Out:
# (4512, 112)

# %% [markdown]
# # Column name checkers on the tables

# %%
list(filter(lambda x: 'profit' in x, list(merged_df.columns)))
# Out:
# ['profit_factor', 'profit_ratio']

# %% [markdown]
# # Filter and sort the Algos based on a certain criteria on the stats
# ## We use the OOS table rather than backtest table, because backtest data tends to be extremely overfit.
# 1. Win Days > 51% - prefer algos that wins more than loss
# 2. CAGR ≤ 1000% - filter out overfit algos
# 3. Start Period on or before 1/1/2024 - prefer stats with at least >1 year of data
# 4. End period on or after 12/2024 - some algo may includes tickers that terminates in between, and thus useless.
# 5. Payoff Ratio ≥ 1.25
# 6. Profit Factor ≥ 1

# %%
def get_date(row, key):
    return '2024-12-28' if isinstance(row[key], float) else row[key][:10]

def extract_start_date(row):
    return pd.to_datetime(get_date(row, 'last_semantic_update_at'))

def extract_last_date(row):
    return pd.to_datetime(get_date(row, 'last_backtest_last_market_day'))

merged_df['backtest_start_date'] = merged_df.apply(extract_start_date, axis=1)
merged_df['backtest_last_date'] = merged_df.apply(extract_last_date, axis=1)

# %%
# df_oos.columns
win_rate_gt_50 = merged_df['win_rate'] > .5 
cagr_lt_1000 = merged_df['cagr'] < 10
oos_start_gt = merged_df['backtest_start_date'] < '2024-01-01'
oos_last_day = merged_df['backtest_last_date'] >= '2024-12-29'
payoff_gt = merged_df['payoff_ratio'] >= 1.25
profit_gt = merged_df['profit_factor'] >= 1
filter_cols = ['symphony_sid', 'title', 'smart_sharpe', 'win_rate', 'cagr', 'payoff_ratio', 'profit_factor', 'backtest_start_date']
merged_df[
    win_rate_gt_50 & cagr_lt_1000 & oos_start_gt & oos_last_day & payoff_gt & profit_gt
][
    filter_cols
].sort_values(by = ['cagr'], ascending=False).head(50)
# Out:
#               symphony_sid                                              title  \
# 1759  wadbe3IfwvSES5vk6yiu  TESTPORT #019: Top Cap by MA + RSI ETF Hedge |...
# 2400  10gAZFrWUyt0yKglAD6O              Monthly MAR SS · Strategy on Composer
# 1157  4nRRutmlzZpacQYQCrXs     NVDA or V1a Simple Sort · Strategy on Composer
# 2306  mPEwXoPyph4KDiTqIY97                                       V1b A Better
# 3592  oMx2o5HqFfQSa9n1Se8i  V1a Simple Portfolio (UVXY) + BB V3.0.4.2A mer...
# 4293  vLfcx19DP0jTKjVSt4da  V1a Simple Portfolio (UVXY) + BB V3.0.4.2A mer...
# 1331  Kak9fBeaxnTfhM7oBSZn                        Rage · Strategy on Composer
# 1506  5LyrJXtkTrV1xzxjfqjd  V1a Simple Portfolio (UVXY) + v4 Pops + BB V3....
# 3583  8LNlmTgqsYnOOQ2RXMOo  V1a Simple Portfolio (UVXY) + v4 Pops · Strate...
# 558   bfDWmOdCVXh1xHw92AdJ  Ease Up on the Gas V2a (add a little nitro) · ...
# 2943  MzhTJqzPLSeiGxy4ODYi  V1a Simple Portfolio (UVXY) · Strategy on Comp...
# 1084  IOFAolCvAQScVNDv9JJx      What More Do You Need? · Strategy on Composer
# 1488  AEqf2PtW5Brr4DLTGo0P  Ease Up on the Gas V2a (add a little nitro) (I...
# 3591  wTw6ou41cm2PhXfMz42P  Simple Portfolio (UVXY) + BB V3.0.4.2A merged ...
# 3589  MJe3lvlFcU3MR1BVq7uM  Simple Portfolio (UVXY) + v4 Pops + BB V3.0.4....
# 2152  MxXhxsDNyP1e6DwG1g4f  The Sauce - RTFM | Deez | 8JUL2023 · Strategy ...
# 3619  aFqMH2vdkuYOwcMQtnyY  Simple Portfolio (UVXY) + v4 Pops + V1a TQQQ o...
# 1356  FPBF32NF99YRqt74cwG4  ⚛️ Beta Baller Reloaded V1 | Deez | 9JUN2023 ·...
# 3582  dOOauhey3mavaTPPVZ0q  Simple Portfolio (UVXY) + v4 Pops · Strategy o...
# 3620  S18E9zBOtod2iSlltX1V  V1a Simple Portfolio (UVXY) + v4 Pops + V1a TQ...
# 3683  6BlFMzNoTdvzXQYdRs6k   V1a Most used assets w/3x · Strategy on Composer
# 547   NOiHFTzmlLANxUiSYAFQ  V1a TQQQ or not | + Dash of SQQQ w/ V1a Simple...
# 1299  frr6MKYDf44DSPy2a0zv             Composer – Automated trading platform.
# 3753  dUld7XJSwzyocKKZq1t4  Better Ballers - RSI Sort 10.1.23 · Strategy o...
# 2413  6WWFGt4yIKRaj6E9wGwZ            V2 Stock Surfing · Strategy on Composer
# 103   UcEdbLxz7BUGsBy0YRbf  V 1.0 | ☢️ NASDAQ 20 DeETF | Deez | AR: 64.1% ...
# 3622  Q4edUvaEB7lYA038OgNn  TQQQ or not | + Dash of SQQQ w/Simple Portfoli...
# 1952  wx89z5cyImxAamUuNyxX  [weekly] ?? NASDAQ-X DeETF | $Deez | BT - 14NO...
# 3318  I39wonWnAePdxXMUMDiv  Cautious Fund Surfing | 3x (Invest Copy) · Str...
# 3686  G3BSPN8nx7oNpYRrFHLz              V1 BWC BTD/STR · Strategy on Composer
# 3210  Bc9AZyrxsi12MCxPkQts  SPY, Energy, Chips, Commodities 🦢+V1 New SOXL ...
# 3334  JSSjcR5zyP2fZn4xyhNw  Dereck The Bond Whisperer | 11JUN2023 (Invest ...
# 573   0xlSHoS9ea7YM9sAnlfl  Dereck The Bond Whisperer | 11JUN2023 · Strate...
# 3881  eOs8ksBybKcRbvy8HMqS                New Symphony · Strategy on Composer
# 2412  oMSC6CujvudCMYfadSRy   V2 Direxion Stock Surfing · Strategy on Composer
# 367   UCdPGf2Ym4FeTq52nHQZ   V1 | JEPI Jedi | HinnomTX · Strategy on Composer
# 1779  0BfsbDtcVcDNFVEsQgra                   TQQQ/SQQQ · Strategy on Composer
# 570   Erqhn1qppgjzh60Tfje6  [?T] Pop Bot W/ 1x 60/40 (Private Copy) · Stra...
# 400   o3Gjzvmp0bJIMiUBb44c  Vol Hedge ? 2.0 - Replace TQQQ w/ TECL · Strat...
# 149   os3RnD25lMXOlHQFy69p  7. Pop Bot W/ 1x 60/40 (INVEST) | TLT VS SHY E...
# 393   GWqaAjHXeXnzCoXlm8Ew                 Vol Hedge ? · Strategy on Composer
# 411   utve73kWTnkXQu3zocGW              Beta Hedge 3.0 · Strategy on Composer
# 395   vhCYar77Bl6JdPdbAnhm             Vol Hedge ? 2.0 · Strategy on Composer
# 1938  9PuMw0m5LeHa7ZqfpXsM  Safety Town v1.4 w/ Pop Bots v1.0 · Strategy o...
# 445   B5CIIwlHTQGq02ocYisi  YINN/YANG Challenge - Luke (Original) · Strate...
# 1087  MGDdjd0HYaDjI1ytzBFv  LS Vix - TG 8,40-62.5% SVOL · Strategy on Comp...
# 2076  A2ioLOOs13YguciW4Jhs  Sector Selector Ninja Mode · Strategy on Composer
# 3580  foCZfVroBUDX69CIjxUV  Zero Beta Dividends - 8 Feb 2018 · Strategy on...
# 2414  9dODrMYBJmroPZ1F8J0e   V2 Yieldmax Stock Surfing · Strategy on Composer
# 108   ltYJfAbjNyUjIrA2TQyS    Buy the Dips: Nasdaq 100 · Strategy on Composer
#
#       smart_sharpe  win_rate      cagr  payoff_ratio  profit_factor  \
# 1759      2.187080  0.556701  1.886272      1.272242       1.597700
# 2400      2.044197  0.534884  1.082108      1.288520       1.481798
# 1157      2.027890  0.537879  0.875719      1.307850       1.522252
# 2306      2.154799  0.547794  0.858497      1.257019       1.522731
# 3592      2.231058  0.577830  0.827675      1.253758       1.716037
# 4293      2.231058  0.577830  0.827675      1.253758       1.716037
# 1331      2.351413  0.583924  0.803142      1.267031       1.778163
# 1506      2.351413  0.583924  0.803142      1.267031       1.778163
# 3583      2.168592  0.568396  0.740002      1.292272       1.701845
# 558       1.664646  0.576531  0.729495      1.411190       1.921259
# 2943      2.140526  0.556604  0.719042      1.330363       1.670030
# 1084      1.589599  0.504918  0.717688      1.327990       1.354374
# 1488      1.638245  0.575064  0.711805      1.400576       1.895391
# 3591      2.240233  0.577830  0.704542      1.252104       1.713774
# 3589      2.339780  0.582547  0.669904      1.260640       1.759199
# 2152      1.458574  0.501348  0.668930      1.287630       1.294590
# 3619      2.160670  0.570048  0.657345      1.265285       1.677569
# 1356      1.234321  0.504021  0.633247      1.253358       1.273683
# 3582      2.196852  0.561321  0.616273      1.321974       1.691558
